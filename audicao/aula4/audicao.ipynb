# %%
import librosa
from IPython.display import Audio

# %%
file_path = "male.wav"
samples, sampling_rate = librosa.load(file_path, sr=None,mono=True,offset= 0.0, duration=None)
len(samples), sampling_rate
# Out:
# (88064, 16000)

# %% [markdown]
# sampling_rate = 16k says that this audio was recored(sampled) with a sampling frequency of 16k.
#
# In other words, while recording this file we were captureing 16000 amplitudes every second.
#
# Thus, if we want to know the duration of the audio, we can simply divide the number of samples (amplitudes) by the sampling-rate as shown below.

# %%
duration_of_sound = len(samples)/sampling_rate
print(f'duration_of_sound = {duration_of_sound}s')
# Out:
# duration_of_sound = 5.504s

# %%
Audio(file_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
